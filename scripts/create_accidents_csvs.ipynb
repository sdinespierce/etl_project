# %%
import pandas as pd

# %%
full_ny_accidents_df = pd.read_csv("../Data/NY_accidents.csv")

full_ny_accidents_df.rename(columns={"ID": "Accident_ID"}, inplace=True)
full_ny_accidents_df.head()
# Out:
#    Unnamed: 0 Accident_ID  Severity           Start_Time             End_Time  \
# 0          11        A-12         2  2020-12-17 16:38:09  2020-12-17 19:36:53
# 1          19        A-20         2  2020-04-18 14:41:08  2020-04-18 15:25:50
# 2          24        A-25         2  2020-06-25 14:48:35  2020-06-25 15:03:35
# 3          31        A-32         3  2018-11-28 07:47:31  2018-11-28 08:17:21
# 4          39        A-40         2  2020-12-22 00:44:00  2020-12-22 04:51:36
#
#    Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  ... Roundabout  \
# 0  40.912210 -73.875099  40.916901 -73.871440         0.376  ...      False
# 1  41.556862 -73.779556  41.556862 -73.779556         0.000  ...      False
# 2  40.912200 -73.884610  40.912200 -73.884610         0.000  ...      False
# 3  43.003693 -78.412064  43.003693 -78.412064         0.000  ...      False
# 4  43.100197 -77.547005  43.099092 -77.546755         0.077  ...      False
#
#    Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0    False  False           False          False        False          Night
# 1    False  False           False          False        False            Day
# 2    False  False           False          False        False            Day
# 3    False  False           False          False        False            Day
# 4    False  False           False           True        False          Night
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2            Day               Day                   Day
# 3            Day               Day                   Day
# 4          Night             Night                 Night
#
# [5 rows x 48 columns]

# %%
# Create NY_Accidents Table
# 
accidents_df = full_ny_accidents_df[['Accident_ID', 'Severity', 'Distance(mi)', 'Description']]
accidents_df['Severity'] = accidents_df['Severity'].astype(int)
accidents_df.dtypes
# Out:
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# Accident_ID      object
# Severity          int32
# Distance(mi)    float64
# Description      object
# dtype: object

# %%
# Create Time Table
# 
time_df = full_ny_accidents_df[['Accident_ID', 'Start_Time', 'End_Time', 'Sunrise_Sunset']]

time_df['Start_Time']= pd.to_datetime(time_df['Start_Time'])
time_df['End_Time']= pd.to_datetime(time_df['End_Time'])
time_df.dtypes
# Out:
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Accident_ID               object
# Start_Time        datetime64[ns]
# End_Time          datetime64[ns]
# Sunrise_Sunset            object
# dtype: object

# %%
# Create Lat_Lng Table
# 
Lat_Lng_df = full_ny_accidents_df[['Accident_ID', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng']]
Lat_Lng_df.dtypes
# Out:
# Accident_ID     object
# Start_Lat      float64
# Start_Lng      float64
# End_Lat        float64
# End_Lng        float64
# dtype: object

# %%
# Create Weather Table
# 
Weather_df = full_ny_accidents_df[['Accident_ID', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition']]
Weather_df.dtypes
# Out:
# Accident_ID           object
# Weather_Timestamp     object
# Temperature(F)       float64
# Wind_Chill(F)        float64
# Humidity(%)          float64
# Pressure(in)         float64
# Visibility(mi)       float64
# Wind_Direction        object
# Wind_Speed(mph)      float64
# Precipitation(in)    float64
# Weather_Condition     object
# dtype: object

# %%
# Create infrastructure Table
# TODO: Check Types
# 
infrastructure_df = full_ny_accidents_df[['Accident_ID', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop']]
infrastructure_df['Bump'] = infrastructure_df['Bump'].replace({True: 1, False: 0})
infrastructure_df['Crossing'] = infrastructure_df['Crossing'].replace({True: 1, False: 0})
infrastructure_df['Give_Way'] = infrastructure_df['Give_Way'].replace({True: 1, False: 0})
infrastructure_df['Junction'] = infrastructure_df['Junction'].replace({True: 1, False: 0})
infrastructure_df['No_Exit'] = infrastructure_df['No_Exit'].replace({True: 1, False: 0})
infrastructure_df['Railway'] = infrastructure_df['Railway'].replace({True: 1, False: 0})
infrastructure_df['Roundabout'] = infrastructure_df['Roundabout'].replace({True: 1, False: 0})
infrastructure_df['Station'] = infrastructure_df['Station'].replace({True: 1, False: 0})
infrastructure_df['Stop'] = infrastructure_df['Stop'].replace({True: 1, False: 0})
infrastructure_df['Traffic_Calming'] = infrastructure_df['Traffic_Calming'].replace({True: 1, False: 0})
infrastructure_df['Traffic_Signal'] = infrastructure_df['Traffic_Signal'].replace({True: 1, False: 0})
infrastructure_df['Turning_Loop'] = infrastructure_df['Turning_Loop'].replace({True: 1, False: 0})
infrastructure_df['Turning_Loop'] = infrastructure_df['Turning_Loop'].astype(int)
infrastructure_df.dtypes
# Out:
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Sam\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Accident_ID        object
# Bump                int64
# Crossing            int64
# Give_Way            int64
# Junction            int64
# No_Exit             int64
# Railway             int64
# Roundabout          int64
# Station             int64
# Stop                int64
# Traffic_Calming     int64
# Traffic_Signal      int64
# Turning_Loop        int32
# dtype: object

# %%
# export to csv files

time_df.to_csv("../Data/db_table_csvs/Time.csv")
Lat_Lng_df.to_csv("../Data/db_table_csvs/Lat_Lng.csv")
Weather_df.to_csv("../Data/db_table_csvs/Weather.csv")
infrastructure_df.to_csv("../Data/db_table_csvs/Infrastructure.csv")
