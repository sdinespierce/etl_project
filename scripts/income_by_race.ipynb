# %%
# Mike
import pandas as pd

# %%
#read in
income_by_race_df = pd.read_csv('../Data/clean_income_by_location.csv')
income_by_race_df.head()
# Out:
#     Race  Year  Household Income by Race  Household Income by Race Moe  \
# 0  Total  2019                     69953                        4889.0
# 1  Total  2019                     41432                        1090.0
# 2  Total  2019                     52010                        3777.0
# 3  Total  2019                     50912                        2594.0
# 4  Total  2019                     58665                        4419.0
#
#                County State
# 0       Albany County    NY
# 1        Bronx County    NY
# 2       Broome County    NY
# 3  Cattaraugus County    NY
# 4       Cayuga County    NY

# %%
# Create Race Table
race_df = income_by_race_df[['Race']]
race_df.Race.unique()
race_df.drop(['Total'])
race_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-a682ad4d9510> in <module>
#       2 race_df = income_by_race_df[['Race']]
#       3 race_df.Race.unique()
# ----> 4 race_df.drop(['Total'])
#       5 race_df
#
# ~\OneDrive\Documents\c\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\OneDrive\Documents\c\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
# Create Household Income By Race Table
race_df = income_by_race_df[['Year','Household Income by Race', 'Household Income by Race Moe']]
race_df
# Out:
#       Year  Household Income by Race  Household Income by Race Moe
# 0     2019                     69953                        4889.0
# 1     2019                     41432                        1090.0
# 2     2019                     52010                        3777.0
# 3     2019                     50912                        2594.0
# 4     2019                     58665                        4419.0
# ...    ...                       ...                           ...
# 1974  2013                     25847                        6356.0
# 1975  2013                     45037                       28859.0
# 1976  2013                     37361                       29732.0
# 1977  2013                     40253                       22919.0
# 1978  2013                     53423                        6260.0
#
# [1979 rows x 3 columns]
