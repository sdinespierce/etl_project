# %%
import pandas as pd

# %%
census_df_2016=pd.read_csv("census_2016_county.csv")
census_df_2016.head()
# Out:
#              COUNTY, STATE  POPULATION                          DATE  \
# 0  Baldwin County, Alabama      208563  7/1/2016 population estimate
# 1  Barbour County, Alabama       25965  7/1/2016 population estimate
# 2     Bibb County, Alabama       22643  7/1/2016 population estimate
# 3   Blount County, Alabama       57704  7/1/2016 population estimate
# 4  Bullock County, Alabama       10362  7/1/2016 population estimate
#
#    State Code  County Code
# 0           1            3
# 1           1            5
# 2           1            7
# 3           1            9
# 4           1           11

# %%
census_df_2017=pd.read_csv("census_2017_county.csv")
census_df_2017.head()
# Out:
#                COUNTY, STATE  POPULATION                          DATE  \
# 0    Conecuh County, Alabama       12469  7/1/2017 population estimate
# 1      Coosa County, Alabama       10754  7/1/2017 population estimate
# 2  Covington County, Alabama       37092  7/1/2017 population estimate
# 3   Crenshaw County, Alabama       13871  7/1/2017 population estimate
# 4    Cullman County, Alabama       82755  7/1/2017 population estimate
#
#    State Code  County Code
# 0           1           35
# 1           1           37
# 2           1           39
# 3           1           41
# 4           1           43

# %%
census_df_2018=pd.read_csv("census_2018_county.csv")
census_df_2018.head()
# Out:
#              COUNTY, STATE  POPULATION                          DATE  \
# 0  Autauga County, Alabama       55601  7/1/2018 population estimate
# 1  Baldwin County, Alabama      218022  7/1/2018 population estimate
# 2  Barbour County, Alabama       24881  7/1/2018 population estimate
# 3     Bibb County, Alabama       22400  7/1/2018 population estimate
# 4   Blount County, Alabama       57840  7/1/2018 population estimate
#
#    State Code  County Code
# 0           1            1
# 1           1            3
# 2           1            5
# 3           1            7
# 4           1            9

# %%
census_df_2019=pd.read_csv("census_2019_county.csv")
census_df_2019.head()
# Out:
#                   COUNTY, STATE  POPULATION                          DATE  \
# 0    Hidalgo County, New Mexico        4198  7/1/2019 population estimate
# 1     Hudson County, New Jersey      672391  7/1/2019 population estimate
# 2  Hunterdon County, New Jersey      124371  7/1/2019 population estimate
# 3     Morris County, New Jersey      491845  7/1/2019 population estimate
# 4   McKinley County, New Mexico       71367  7/1/2019 population estimate
#
#    State Code  County Code
# 0          35           23
# 1          34           17
# 2          34           19
# 3          34           27
# 4          35           31

# %%
New_York_census_df_2016=census_df_2016[census_df_2016['COUNTY, STATE'].str.contains("New York")]
New_York_census_df_2016.head()
# Out:
#                      COUNTY, STATE  POPULATION                          DATE  \
# 2116       Albany County, New York      308846  7/1/2016 population estimate
# 2139     Allegany County, New York       47077  7/1/2016 population estimate
# 2140        Bronx County, New York     1455720  7/1/2016 population estimate
# 2141       Broome County, New York      195334  7/1/2016 population estimate
# 2142  Cattaraugus County, New York       77677  7/1/2016 population estimate
#
#       State Code  County Code
# 2116          36            1
# 2139          36            3
# 2140          36            5
# 2141          36            7
# 2142          36            9

# %%
New_York_census_df_2017=census_df_2017[census_df_2017['COUNTY, STATE'].str.contains("New York")]
New_York_census_df_2017.head()
# Out:
#                     COUNTY, STATE  POPULATION                          DATE  \
# 1461      Monroe County, New York      747642  7/1/2017 population estimate
# 1462  Montgomery County, New York       49258  7/1/2017 population estimate
# 1463      Nassau County, New York     1369514  7/1/2017 population estimate
# 1464    New York County, New York     1664727  7/1/2017 population estimate
# 1465     Niagara County, New York      211328  7/1/2017 population estimate
#
#       State Code  County Code
# 1461          36           55
# 1462          36           57
# 1463          36           59
# 1464          36           61
# 1465          36           63

# %%
New_York_census_df_2018=census_df_2018[census_df_2018['COUNTY, STATE'].str.contains("New York")]
New_York_census_df_2018.head()
# Out:
#                      COUNTY, STATE  POPULATION                          DATE  \
# 1828       Albany County, New York      307117  7/1/2018 population estimate
# 1829     Allegany County, New York       46430  7/1/2018 population estimate
# 1830        Bronx County, New York     1432132  7/1/2018 population estimate
# 1831       Broome County, New York      191659  7/1/2018 population estimate
# 1832  Cattaraugus County, New York       76840  7/1/2018 population estimate
#
#       State Code  County Code
# 1828          36            1
# 1829          36            3
# 1830          36            5
# 1831          36            7
# 1832          36            9

# %%
New_York_census_df_2019=census_df_2019[census_df_2019['COUNTY, STATE'].str.contains("New York")]
New_York_census_df_2019.head()
# Out:
#                     COUNTY, STATE  POPULATION                          DATE  \
# 117        Bronx County, New York     1418207  7/1/2019 population estimate
# 232     Onondaga County, New York      460528  7/1/2019 population estimate
# 1038   Schoharie County, New York       30999  7/1/2019 population estimate
# 1039      Fulton County, New York       53383  7/1/2019 population estimate
# 1040  Rensselaer County, New York      158714  7/1/2019 population estimate
#
#       State Code  County Code
# 117           36            5
# 232           36           67
# 1038          36           95
# 1039          36           35
# 1040          36           83

# %%
searchfor=['New York County','Kings County','Bronx County', 'Richmond County', 'Queens County', 'Suffolk County', 'Nassau County']
New_York_City_2016_Census_df=New_York_census_df_2016[New_York_census_df_2016['COUNTY, STATE'].str.contains('|'.join(searchfor))]
New_York_City_2016_Census_df
# Out:
#                   COUNTY, STATE  POPULATION                          DATE  \
# 2140     Bronx County, New York     1455720  7/1/2016 population estimate
# 2222     Kings County, New York     2629150  7/1/2016 population estimate
# 2249    Nassau County, New York     1361500  7/1/2016 population estimate
# 2250  New York County, New York     1643734  7/1/2016 population estimate
# 2280    Queens County, New York     2333054  7/1/2016 population estimate
# 2302  Richmond County, New York      476015  7/1/2016 population estimate
# 2331   Suffolk County, New York     1492583  7/1/2016 population estimate
#
#       State Code  County Code
# 2140          36            5
# 2222          36           47
# 2249          36           59
# 2250          36           61
# 2280          36           81
# 2302          36           85
# 2331          36          103

# %%
searchfor=['New York County','Kings County','Bronx County', 'Richmond County', 'Queens County', 'Suffolk County', 'Nassau County']
New_York_City_2017_Census_df=New_York_census_df_2017[New_York_census_df_2017['COUNTY, STATE'].str.contains('|'.join(searchfor))]
New_York_City_2017_Census_df
# Out:
#                   COUNTY, STATE  POPULATION                          DATE  \
# 1463    Nassau County, New York     1369514  7/1/2017 population estimate
# 1464  New York County, New York     1664727  7/1/2017 population estimate
# 1511    Queens County, New York     2358582  7/1/2017 population estimate
# 1513  Richmond County, New York      479458  7/1/2017 population estimate
# 1558   Suffolk County, New York     1492953  7/1/2017 population estimate
# 1823     Kings County, New York     2648771  7/1/2017 population estimate
# 2154     Bronx County, New York     1471160  7/1/2017 population estimate
#
#       State Code  County Code
# 1463          36           59
# 1464          36           61
# 1511          36           81
# 1513          36           85
# 1558          36          103
# 1823          36           47
# 2154          36            5

# %%
searchfor=['New York County','Kings County','Bronx County', 'Richmond County', 'Queens County', 'Suffolk County', 'Nassau County']
New_York_City_2018_Census_df=New_York_census_df_2018[New_York_census_df_2018['COUNTY, STATE'].str.contains('|'.join(searchfor))]
New_York_City_2018_Census_df
# Out:
#                   COUNTY, STATE  POPULATION                          DATE  \
# 1830     Bronx County, New York     1432132  7/1/2018 population estimate
# 1851     Kings County, New York     2582830  7/1/2018 population estimate
# 1857    Nassau County, New York     1358343  7/1/2018 population estimate
# 1858  New York County, New York     1628701  7/1/2018 population estimate
# 1868    Queens County, New York     2278906  7/1/2018 population estimate
# 1870  Richmond County, New York      476179  7/1/2018 population estimate
# 1879   Suffolk County, New York     1481093  7/1/2018 population estimate
#
#       State Code  County Code
# 1830          36            5
# 1851          36           47
# 1857          36           59
# 1858          36           61
# 1868          36           81
# 1870          36           85
# 1879          36          103

# %%
searchfor=['New York County','Kings County','Bronx County', 'Richmond County', 'Queens County', 'Suffolk County', 'Nassau County']
New_York_City_2019_Census_df=New_York_census_df_2019[New_York_census_df_2019['COUNTY, STATE'].str.contains('|'.join(searchfor))]
New_York_City_2019_Census_df
# Out:
#                   COUNTY, STATE  POPULATION                          DATE  \
# 117      Bronx County, New York     1418207  7/1/2019 population estimate
# 1042    Queens County, New York     2253858  7/1/2019 population estimate
# 1044  New York County, New York     1628706  7/1/2019 population estimate
# 1287    Nassau County, New York     1356924  7/1/2019 population estimate
# 1290   Suffolk County, New York     1476601  7/1/2019 population estimate
# 2273     Kings County, New York     2559903  7/1/2019 population estimate
# 2282  Richmond County, New York      476143  7/1/2019 population estimate
#
#       State Code  County Code
# 117           36            5
# 1042          36           81
# 1044          36           61
# 1287          36           59
# 1290          36          103
# 2273          36           47
# 2282          36           85

# %%
Combined_New_York_City_Census_df = pd.concat([New_York_City_2016_Census_df, New_York_City_2017_Census_df, New_York_City_2018_Census_df,New_York_City_2019_Census_df], axis=0)
Combined_New_York_City_Census_df
# Out:
#                   COUNTY, STATE  POPULATION                          DATE  \
# 2140     Bronx County, New York     1455720  7/1/2016 population estimate
# 2222     Kings County, New York     2629150  7/1/2016 population estimate
# 2249    Nassau County, New York     1361500  7/1/2016 population estimate
# 2250  New York County, New York     1643734  7/1/2016 population estimate
# 2280    Queens County, New York     2333054  7/1/2016 population estimate
# 2302  Richmond County, New York      476015  7/1/2016 population estimate
# 2331   Suffolk County, New York     1492583  7/1/2016 population estimate
# 1463    Nassau County, New York     1369514  7/1/2017 population estimate
# 1464  New York County, New York     1664727  7/1/2017 population estimate
# 1511    Queens County, New York     2358582  7/1/2017 population estimate
# 1513  Richmond County, New York      479458  7/1/2017 population estimate
# 1558   Suffolk County, New York     1492953  7/1/2017 population estimate
# ...
