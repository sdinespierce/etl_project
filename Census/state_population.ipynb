# %%
#T.BRADFORD
#July 2021
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
from datetime import datetime
from census import Census

# Census API Key
from config import api_key

# %%
# Run Census Search to retrieve population data
url_2019_state ="https://api.census.gov/data/2019/pep/population?get=NAME,POP,DATE_DESC&for=state:*&key="+api_key
response = requests.get(url_2019_state)
response_json = response.json()

# %%
#Create and rename Dataframe
census_2019_state = pd.DataFrame(response.json()[1:], columns=response.json()[0]).rename(columns=
{"NAME":"STATE", "POP":"POPULATION","DATE_DESC":"DATE","state":"State Code"})
census_2019_state["POPULATION"].astype(int)

#string split
census_2019_state[['DATE', 'Trash']] = census_2019_state['DATE'].str.split(' ', 1, expand=True)

#convert Date to a datetime object
census_2019_state['DATE'] = pd.to_datetime(census_2019_state['DATE'])

#reduced dataframe
census_2019_state = census_2019_state[["STATE","POPULATION","DATE"]]

census_2019_state
# Out:
#                    STATE POPULATION       DATE
# 0            Mississippi    2976149 2019-07-01
# 1               Missouri    6137428 2019-07-01
# 2                Montana    1068778 2019-07-01
# 3               Nebraska    1934408 2019-07-01
# 4                 Nevada    3080156 2019-07-01
# 5          New Hampshire    1359711 2019-07-01
# 6             New Jersey    8882190 2019-07-01
# 7             New Mexico    2096829 2019-07-01
# 8               New York   19453561 2019-07-01
# 9         North Carolina   10488084 2019-07-01
# 10          North Dakota     762062 2019-07-01
# 11                  Ohio   11689100 2019-07-01
# 12              Oklahoma    3956971 2019-07-01
# 13                Oregon    4217737 2019-07-01
# 14          Pennsylvania   12801989 2019-07-01
# 15          Rhode Island    1059361 2019-07-01
# 16        South Carolina    5148714 2019-07-01
# 17          South Dakota     884659 2019-07-01
# 18             Tennessee    6829174 2019-07-01
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_2019_state.to_csv("census_2019_state.csv", encoding="utf-8", index=False)

# %%
# Run Census Search to retrieve population data
url_2018_state ="https://api.census.gov/data/2018/pep/population?get=GEONAME,POP,DATE_DESC&for=state:*&key="+api_key
response = requests.get(url_2018_state)
response_json = response.json()

# %%
#Create and rename Dataframe
census_2018_state = pd.DataFrame(response.json()[1:], columns=response.json()[0]).rename(columns=
{"GEONAME":"STATE", "POP":"POPULATION","DATE_DESC":"DATE","state":"State Code"})
census_2018_state["POPULATION"].astype(int)

#string split
census_2018_state[['DATE', 'Trash']] = census_2018_state['DATE'].str.split(' ', 1, expand=True)

#convert Date to a datetime object
census_2018_state['DATE'] = pd.to_datetime(census_2018_state['DATE'])

#reduced dataframe
census_2018_state = census_2018_state[["STATE","POPULATION","DATE"]]

census_2018_state
# Out:
#                    STATE POPULATION       DATE
# 0                Alabama    4887871 2018-07-01
# 1                 Alaska     737438 2018-07-01
# 2                Arizona    7171646 2018-07-01
# 3               Arkansas    3013825 2018-07-01
# 4             California   39557045 2018-07-01
# 5               Colorado    5695564 2018-07-01
# 6            Connecticut    3572665 2018-07-01
# 7               Delaware     967171 2018-07-01
# 8   District of Columbia     702455 2018-07-01
# 9                Florida   21299325 2018-07-01
# 10               Georgia   10519475 2018-07-01
# 11                Hawaii    1420491 2018-07-01
# 12                 Idaho    1754208 2018-07-01
# 13              Illinois   12741080 2018-07-01
# 14               Indiana    6691878 2018-07-01
# 15                  Iowa    3156145 2018-07-01
# 16                Kansas    2911505 2018-07-01
# 17              Kentucky    4468402 2018-07-01
# 18             Louisiana    4659978 2018-07-01
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_2018_state.to_csv("census_2018_state.csv", encoding="utf-8", index=False)

# %%
# Run Census Search to retrieve population data
url_2017_state ="https://api.census.gov/data/2017/pep/population?get=GEONAME,POP,DATE_DESC&for=state:*&key="+api_key
response = requests.get(url_2017_state)
response_json = response.json()

# %%
#Create and rename Dataframe
census_2017_state = pd.DataFrame(response.json()[1:], columns=response.json()[0]).rename(columns=
{"GEONAME":"STATE", "POP":"POPULATION","DATE_DESC":"DATE","state":"State Code"})
census_2017_state["POPULATION"].astype(int)

#string split
census_2017_state[['DATE', 'Trash']] = census_2017_state['DATE'].str.split(' ', 1, expand=True)

#convert Date to a datetime object
census_2017_state['DATE'] = pd.to_datetime(census_2017_state['DATE'])

#reduced dataframe
census_2017_state = census_2017_state[["STATE","POPULATION","DATE"]]

census_2017_state
# Out:
#                    STATE POPULATION       DATE
# 0   District of Columbia     693972 2017-07-01
# 1                Florida   20984400 2017-07-01
# 2                Georgia   10429379 2017-07-01
# 3                 Hawaii    1427538 2017-07-01
# 4                  Idaho    1716943 2017-07-01
# 5               Illinois   12802023 2017-07-01
# 6                Indiana    6666818 2017-07-01
# 7                   Iowa    3145711 2017-07-01
# 8                 Kansas    2913123 2017-07-01
# 9               Kentucky    4454189 2017-07-01
# 10             Louisiana    4684333 2017-07-01
# 11                 Maine    1335907 2017-07-01
# 12              Maryland    6052177 2017-07-01
# 13         Massachusetts    6859819 2017-07-01
# 14               Alabama    4874747 2017-07-01
# 15                Alaska     739795 2017-07-01
# 16               Arizona    7016270 2017-07-01
# 17              Arkansas    3004279 2017-07-01
# 18            California   39536653 2017-07-01
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_2017_state.to_csv("census_2017_state.csv", encoding="utf-8", index=False)

# %%
# Run Census Search to retrieve population data
url_2016_state ="https://api.census.gov/data/2016/pep/population?get=GEONAME,POP,DATE_DESC&for=state:*&key="+api_key
response = requests.get(url_2016_state)
response_json = response.json()

# %%
#Create and rename Dataframe
census_2016_state = pd.DataFrame(response.json()[1:], columns=response.json()[0]).rename(columns=
{"GEONAME":"STATE", "POP":"POPULATION","DATE_DESC":"DATE","state":"State Code"})
census_2016_state["POPULATION"].astype(int)

#string split
census_2016_state[['DATE', 'Trash']] = census_2016_state['DATE'].str.split(' ', 1, expand=True)

#convert Date to a datetime object
census_2016_state['DATE'] = pd.to_datetime(census_2016_state['DATE'])

#reduced dataframe
census_2016_state = census_2016_state[["STATE","POPULATION","DATE"]]
census_2016_state
# Out:
#                    STATE POPULATION       DATE
# 0                 Alaska     741894 2016-07-01
# 1                Arizona    6931071 2016-07-01
# 2               Arkansas    2988248 2016-07-01
# 3             California   39250017 2016-07-01
# 4               Colorado    5540545 2016-07-01
# 5            Connecticut    3576452 2016-07-01
# 6               Delaware     952065 2016-07-01
# 7   District of Columbia     681170 2016-07-01
# 8                Florida   20612439 2016-07-01
# 9                Georgia   10310371 2016-07-01
# 10                Hawaii    1428557 2016-07-01
# 11                 Idaho    1683140 2016-07-01
# 12              Illinois   12801539 2016-07-01
# 13               Indiana    6633053 2016-07-01
# 14                  Iowa    3134693 2016-07-01
# 15                Kansas    2907289 2016-07-01
# 16              Kentucky    4436974 2016-07-01
# 17             Louisiana    4681666 2016-07-01
# 18                 Maine    1331479 2016-07-01
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_2016_state.to_csv("census_2016_state.csv", encoding="utf-8", index=False)
